# %%
import os
os.chdir("/home/dunland/github/qScope/qScope_frontend/")
import q100viz.session as session

bd = session.buildings.df
# Out:
# pygame 2.1.2 (SDL 2.0.16, Python 3.10.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
for i, (cell, coords) in enumerate(session.grid_1.rects_transformed):
    print("{0}: ({1}|{2}): {3}".format(i, cell.x, cell.y, coords))

# %%
import q100viz.graphics.graphs as graphs
graphs.export_compared_energy_costs(
            search_in_folder="/home/dunland/github/qScope/data/outputs/output_20230503_08-46-46",
            outfile="/home/dunland/github/qScope/data/outputs/output_test" + "/energy_prices/energy_prices_groups.png")
